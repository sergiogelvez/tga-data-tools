# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

DF = pd.read_csv('PMMA.csv', sep=';', header=None, names=['tiempo', 'temperatura', 'peso', 'perdida_peso', 'energia_activacion'])
DF.head()

plt.plot(DF.temperatura, DF.energia_activacion)
plt.plot(DF['temperatura'], DF['perdida_peso'])
plt.show()

# %%
DF
# Out:
#           tiempo  temperatura   peso  perdida_peso  energia_activacion
# 0        4.99500       32.155  6.060      100.4310             238.126
# 1        4.99667       32.158  6.060      100.4310             238.031
# 2        4.99833       32.161  6.060      100.4310             237.935
# 3        5.00000       32.164  6.060      100.4310             237.840
# 4        5.00167       32.167  6.060      100.4310             237.745
# 5        5.00333       32.170  6.060      100.4310             237.649
# 6        5.00500       32.173  6.060      100.4310             237.554
# 7        5.00667       32.176  6.060      100.4310             237.458
# 8        5.00833       32.179  6.060      100.4310             237.362
# 9        5.01000       32.182  6.060      100.4310             237.267
# 10       5.01167       32.185  6.060      100.4310             237.171
# 11       5.01333       32.188  6.060      100.4310             237.075
# ...
